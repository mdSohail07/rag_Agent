# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
res= llm.invoke("who is pm of india")

# %%
res.content
# Out:
# 'The current Prime Minister of India is **Narendra\u202fModi**. He has been in office since May\u202f26,\u202f2014, leading the Bharatiya Janata Party (BJP) and its National Democratic Alliance (NDA) coalition.'

# %%
print(res.content)
# Out:
# The current Prime Minister of India is **Narendra Modi**. He has been in office since May 26, 2014, leading the Bharatiya Janata Party (BJP) and its National Democratic Alliance (NDA) coalition.
