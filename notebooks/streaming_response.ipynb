# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b", streaming = True)

# %%
question = "what is genai ?"
res = llm.stream(question)
for chunk in res:
    print(chunk.content, end=" ")
# Out:
#                                                                                                                                                                                                              ** Gen AI  =  Gener ative  AI **
#
#  >  * A  branch  of  artificial  intelligence  that  can  ** create **  new  content — text ,  images ,  audio ,  video ,  code ,  and  more — rather  than  just  classify  or  predict .*
#
#  ---
#
#  ##   1 .    What  it  actually  does
#
#  |  What  it  can  produce  |  Typical  tools  /  models  |  Real ‑ world  examples  |
#  | ---------------- ----- | ---------------- -------- | ---------------- ----- |
#  |  ** Text **  |  GPT ‑ 4 ,  Claude ,  L La MA ,  etc .  |  Chat bots ,  automated  articles ,  code  generation ,  translation ,  summar ization  |
#  |  ** Images **  |  Stable  Diff usion ,  Mid jour ney ,  D ALL ‑ E  |  Concept  art ,  product  mock ‑ ups ,  photo  editing ,  style  transfer  |
#  |  ** Audio **  |  J uk ebox ,  Voice  Cl oning  models  |  Music  composition ,  voice  assistants ,  speech  synthesis  |
#  |  ** Video **  |  Gen ‑ 1 ,  Video GPT ,  Stable  Video  Diff usion  |  Short  video  creation ,  deep f akes ,  animation  |
#  |  ** 3 ‑ D  &  AR **  |  Dream Fusion ,  Point -E  |  Virtual  reality  assets ,  game  design  |
#  |  ** Code **  |  Git Hub  Cop ilot ,  Alpha Code  |  Auto ‑ completion ,  bug  fixes ,  algorithm  suggestions  |
#
#  ---
#
#  ##   2 .    How  it  works  ( in  a  nutshell )
#
#  1 .  ** Training  on  massive  data **
#      -  Models  learn  patterns  by  being  fed  huge  datasets  ( books ,  websites ,  images ,  code ,  etc .).
#      -  The  learning  is  * uns uper vised *  or  * self ‑ super vised *:  the  model  tries  to  predict  the  next  word ,  pixel ,  or  token .
#
#  2 .  ** Transformer  architecture **
#      -  Uses  self ‑ attention  to  capture  long ‑ range  dependencies .
#      -  Allows  the  model  to  generate  coherent  sequences  of  arbitrary  length .
#
#  3 .  ** Fine ‑ t uning  &  prompting **
#      -  After  the  base  model  is  trained ,  it  can  be  fine ‑ t uned  on  a  specific  domain  or  instructed  via  prompts  to  steer  the  output .
#
#  4 .  ** Sampling  &  decoding **
#      -  Techniques  like  temperature ,  top ‑ k ,  nucleus  sampling  control  creativity  vs .  safety .
#
#  ---
#
#  ##   3 .    Why  it  matters
#
#  |  Benefit  |  Impact  |
#  | --------- | -------- |
#  |  ** Speed  &  scale **  |  Generates  content  in  seconds  that  would  take  humans  days .  |
#  |  ** Personal ization **  |  Tail ors  writing  style ,  tone ,  or  design  to  individual  users .  |
#  |  ** Accessibility **  |  Helps  people  with  disabilities  ( e .g .,  generating  captions ,  describing  images ).  |
#  |  ** Innovation **  |  Fu els  new  creative  workflows  in  art ,  music ,  design ,  and  software  engineering .  |
#  |  ** Cost  savings **  |  Red uces  labor  for  routine  or  repetitive  content  creation .  |
#
#  ---
#
#  ##   4 .    Common  misconceptions
#
#  |  Myth  |  Reality  |
#  | ------ | --------- |
#  |  * Gen AI  is  “ magic ”  and  always  perfect .*  |  It ’s  powerful  but  still  prone  to  halluc inations ,  biases ,  and  factual  errors .  |
#  |  * It  replaces  all  human  creators .*  |  It  aug ments  human  creativity ;  many  tasks  still  require  human  judgment .  |
#  |  * All  Gen AI  outputs  are  copyrighted .*  |  Many  outputs  are  public  domain  or  open ‑ source ,  but  ownership  can  be  mur ky — always  check  licensing .  |
#
#  ---
#
#  ##   5 .    Ethical  &  societal  considerations
#
#  -  ** Bias  &  fairness **  –  Models  can  reproduce  societal  biases  present  in  training  data .
#  -  ** M isin formation **  –  Easy  generation  of  realistic  fake  text  or  media .
#  -  ** Int ellectual  property **  –  Questions  about  ownership  of  AI ‑ generated  content .
#  -  ** Job  displacement **  –  Automation  of  certain  creative  or  cler ical  roles .
#  -  ** Environmental  cost **  –  Training  large  models  consumes  significant  energy .
#
#  ---
#
#  ##   6 .    Getting  started
#
#  |  Resource  |  What  you ’ll  learn  |
#  | ---------- | ---------------- --- |
#  |  ** Open AI  Playground **  |  Hands ‑ on  with  GPT ‑ 4 ,  Chat GPT .  |
#  |  ** Diff usion  Studio **  |  Experiment  with  image  generation .  |
#  |  ** H ug ging  Face  Spaces **  |  Try  out  community ‑ built  Gen AI  demos .  |
#  |  ** Fast API  +  Lang Chain **  |  Build  your  own  Gen AI ‑ powered  app .  |
#  |  ** Cour sera :  “ Gener ative  AI ” **  |  Structured  courses  on  theory  &  practice .  |
#
#  ---
#
#  ###  TL ; DR
#
#  ** Gen AI **  ( gener ative  AI )  is  AI  that  * creates *  new  content — text ,  images ,  audio ,  code ,  and  more — using  large ,  transformer ‑ based  models  trained  on  vast  datasets .  It  powers  everything  from  chat bots  and  design  tools  to  music  generators  and  code  assistants ,  offering  huge  productivity  gains  while  raising  important  ethical  questions .
